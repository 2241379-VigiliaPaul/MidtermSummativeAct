# %%
# Exploratory Data Analysis Notebook
# Initial data exploration for Telco Customer Churn dataset

# TODO: Add EDA code here
# - Load data
# - Basic statistics
# - Visualizations
# - Correlation analysis
# - Feature importance exploration
